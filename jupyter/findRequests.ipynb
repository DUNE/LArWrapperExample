# %%
# brute force loop over files in samweb and create a list of requestids with characteristics

# HMS 6-17-2023


import os,time,sys,datetime, glob, fnmatch,string,subprocess, json

import samweb_client
samweb = samweb_client.SAMWebClient(experiment='dune')

#mode = "data"
DEBUG = False
max = 100
# list of things that are particular to that file, not the request
reject = [ 'process_id','event_count','DUNE_data.detector_config','parents','runs', 'file_id', 'create_date','update_date', 'update_user', 'file_size', 'checksum', 'content_status',  'group',  'first_event', 'last_event', 'art.file_format_era', 'art.file_format_version', 'art.first_event', 'art.last_event', 'art.process_name', 'art.run_type']

# %%
def safeget(md,key):
    r = None
    if key in md:
        if type(md[key]) == 'int':
            r = str(md[key])
        else:
            r = md[key]
    return r

# %%
# get a list of first files in runs for mc

# if mode == "mc":
#     query = "user dunepro and file_type mc and data_tier full-reconstructed and first_event 1 and create_date > 2022-01-01 and user dunepro"
# else:
#     query = "user dunepro and file_type detector and first_event 1 and create_date > 2022-01-01 minus data_tier root-tuple"

query = "user dunepro and first_event 1 and create_date > 2022-01-01 minus data_tier root-tuple"
filelist = samweb.listFiles(dimensions=query)

# %%
descrip=""
descriplist = {}
count = 0
for file in filelist:

    count +=1
    if DEBUG and count > max:
        print ("quitting after", count, "files")
        break
    md = samweb.getMetadata(file)
    k = {}
    k["file_type"] = safeget(md,"file_type")
    k["run_type"] = safeget(md,"runs")[0][2]
    md["run_type"] = k["run_type"]
    k["DUNE.requestid"] = safeget(md,"DUNE.requestid")
    k["DUNE.campaign"] = safeget(md,"DUNE.campaign")
    if safeget(md,"application") != None:
        k["version"] = safeget(md,"application")["version"]
    k["data_tier"] = safeget(md,"data_tier")
    k["data_stream"] = safeget(md,"data_stream")
    k["detector.hv_value"] = safeget(md,"detector.hv_value")
    k["beam.momentum"] = safeget(md,"beam.momentum")
    k["DUNE_MC.beam_energy"] = safeget(md,"DUNE_MC.beam_energy")
    k["DUNE_MC.electron_lifetime"] = safeget(md,"DUNE_MC.electron_lifetime")
    k["DUNE_MC.generators"] = safeget(md,"DUNE_MC.generators")
    k["DUNE_MC.liquid_flow"] = safeget(md,"DUNE_MC.liquid_flow")
    k["DUNE_MC.space_charge"] = safeget(md,"DUNE_MC.space_charge")
    k["DUNE_MC.with_cosmics"] = safeget(md,"DUNE_MC.with_cosmics")
                                             

    tag = "TAG_"
    mquery = ""
    for x in k:
        if k[x] != None:
            tag += str(k[x])
            mquery += x + " " + str(k[x]) + " and "
        else:
            tag += "X"
        tag += "___"

    request = tag[:-3]
    mquery = mquery[:-4]


    if request in descriplist: continue

    if DEBUG: print (request)
    if DEBUG: print (mquery) 

    print ("new requestid",request)
    # get rid of a lot of extra metadata

    newreject = []
    for y in md.keys():
        if "DUNE_data" in y:
            newreject.append(y)

    for x in reject:
        if x in md:
            md.pop(x)
    for x in newreject:
        if x in md:
            md.pop(x)

    descriplist[request]=md

    summary = samweb.listFilesSummary(mquery)
    print (mquery, summary)
    descriplist[request]["query"] = mquery
    descriplist[request]["file_count"] = summary["file_count"]
    if summary["total_file_size"] != None:
        descriplist[request]['total_file_size_GB'] = int(summary["total_file_size"]/1000000000)
    else:
        descriplist[request]['total_file_size_GB'] = None
    descriplist[request]["total_event_count"] = summary["total_event_count"]
    if (DEBUG): print (descriplist[request])
# Out:
# new requestid TAG_detector___protodune-sp___X___PDSPProd4___v09_30_00___reco-recalibrated___physics___180___X___X___X___X___X___X___X
# file_type detector and run_type protodune-sp and DUNE.campaign PDSPProd4 and version v09_30_00 and data_tier reco-recalibrated and data_stream physics and detector.hv_value 180  {'file_count': 49115, 'total_file_size': 244499938239381, 'total_event_count': 6430371}
# new requestid TAG_mc___fardet-vd___RITM1276306___FDVDProd1___v09_37_00___full-reconstructed___out1___X___X___X___X___genie_anu___X___X___X
# file_type mc and run_type fardet-vd and DUNE.requestid RITM1276306 and DUNE.campaign FDVDProd1 and version v09_37_00 and data_tier full-reconstructed and data_stream out1 and DUNE_MC.generators genie_anu  {'file_count': 99052, 'total_file_size': 204386756217862, 'total_event_count': 990520}
# new requestid TAG_mc___fardet-vd___RITM1276306___FDVDProd1___v09_37_00___full-reconstructed___out1___X___X___X___X___genie_anu_numu2nutau_nue2numu___X___X___X
# file_type mc and run_type fardet-vd and DUNE.requestid RITM1276306 and DUNE.campaign FDVDProd1 and version v09_37_00 and data_tier full-reconstructed and data_stream out1 and DUNE_MC.generators genie_anu_numu2nutau_nue2numu  {'file_count': 88755, 'total_file_size': 187301262718024, 'total_event_count': 887550}
# new requestid TAG_mc___fardet-vd___RITM1276306___FDVDProd1___v09_37_00___full-reconstructed___out1___X___X___X___X___genie_anu_numu2nue_nue2nutau___X___X___X
# file_type mc and run_type fardet-vd and DUNE.requestid RITM1276306 and DUNE.campaign FDVDProd1 and version v09_37_00 and data_tier full-reconstructed and data_stream out1 and DUNE_MC.generators genie_anu_numu2nue_nue2nutau  {'file_count': 97520, 'total_file_size': 211986178847345, 'total_event_count': 975200}
# new requestid TAG_mc___fardet-vd___RITM1276306___FDVDProd1___v09_37_00___full-reconstructed___out1___X___X___X___X___genie_nu___X___X___X
# file_type mc and run_type fardet-vd and DUNE.requestid RITM1276306 and DUNE.campaign FDVDProd1 and version v09_37_00 and data_tier full-reconstructed and data_stream out1 and DUNE_MC.generators genie_nu  {'file_count': 96466, 'total_file_size': 196913476651704, 'total_event_count': 964660}
# new requestid TAG_mc___fardet-vd___RITM1276306___FDVDProd1___v09_37_00___full-reconstructed___out1___X___X___X___X___genie_nu_numu2nue_nue2nutau___X___X___X
# file_type mc and run_type fardet-vd and DUNE.requestid RITM1276306 and DUNE.campaign FDVDProd1 and version v09_37_00 and data_tier full-reconstructed and data_stream out1 and DUNE_MC.generators genie_nu_numu2nue_nue2nutau  {'file_count': 98955, 'total_file_size': 209046869021263, 'total_event_count': 989550}
# new requestid TAG_mc___fardet-vd___RITM1276306___FDVDProd1___v09_37_00___full-reconstructed___out1___X___X___X___X___genie_nu_numu2nutau_nue2numu___X___X___X
# file_type mc and run_type fardet-vd and DUNE.requestid RITM1276306 and DUNE.campaign FDVDProd1 and version v09_37_00 and data_tier full-reconstructed and data_stream out1 and DUNE_MC.generators genie_nu_numu2nutau_nue2numu  {'file_count': 103598, 'total_file_size': 214619854641583, 'total_event_count': 1035980}
# new requestid TAG_detector___protodune-sp___X___RITM1312299___v09_09_01___full-reconstructed___cosmics___180___X___X___X___X___X___X___X
# file_type detector and run_type protodune-sp and DUNE.campaign RITM1312299 and version v09_09_01 and data_tier full-reconstructed and data_stream cosmics and detector.hv_value 180  {'file_count': 80562, 'total_file_size': 112120340111538, 'total_event_count': 5192760}
# new requestid TAG_mc___fardet-vd___RITM1276306___FDVDProd1___v09_37_00___full-reconstructed___out1___X___X___X___X___X___X___X___X
# file_type mc and run_type fardet-vd and DUNE.requestid RITM1276306 and DUNE.campaign FDVDProd1 and version v09_37_00 and data_tier full-reconstructed and data_stream out1  {'file_count': 643482, 'total_file_size': 1340656525229750, 'total_event_count': 6434820}
# new requestid TAG_mc___fardet-vd___RITM1276306___FDVDProd1___v09_37_00___full-reconstructed___out1___X___X___X___X___marley___X___X___X
# file_type mc and run_type fardet-vd and DUNE.requestid RITM1276306 and DUNE.campaign FDVDProd1 and version v09_37_00 and data_tier full-reconstructed and data_stream out1 and DUNE_MC.generators marley  {'file_count': 49985, 'total_file_size': 97103370377454, 'total_event_count': 499850}
# new requestid TAG_detector___protodune-sp___X___RITM1312299___v09_30_00___reco-recalibrated___cosmics___180___X___X___X___X___X___X___X
# file_type detector and run_type protodune-sp and DUNE.campaign RITM1312299 and version v09_30_00 and data_tier reco-recalibrated and data_stream cosmics and detector.hv_value 180  {'file_count': 65894, 'total_file_size': 98868412295885, 'total_event_count': 4492443}
# new requestid TAG_detector___protodune-sp___X___RITM1312299___v09_09_01___full-reconstructed___cosmics___0___X___X___X___X___X___X___X
# file_type detector and run_type protodune-sp and DUNE.campaign RITM1312299 and version v09_09_01 and data_tier full-reconstructed and data_stream cosmics and detector.hv_value 0  {'file_count': 30, 'total_file_size': 73592166662, 'total_event_count': 21499}
# new requestid TAG_detector___protodune-sp___X___RITM1312299___v09_09_01___full-reconstructed___cosmics___120___X___X___X___X___X___X___X
# file_type detector and run_type protodune-sp and DUNE.campaign RITM1312299 and version v09_09_01 and data_tier full-reconstructed and data_stream cosmics and detector.hv_value 120  {'file_count': 850, 'total_file_size': 1816512308853, 'total_event_count': 68106}
# new requestid TAG_detector___protodune-sp___X___RITM1312299___v09_09_01___full-reconstructed___cosmics___18___X___X___X___X___X___X___X
# file_type detector and run_type protodune-sp and DUNE.campaign RITM1312299 and version v09_09_01 and data_tier full-reconstructed and data_stream cosmics and detector.hv_value 18  {'file_count': 200, 'total_file_size': 123366558459, 'total_event_count': 12243}
# new requestid TAG_detector___protodune-sp___X___RITM1312299___v09_09_01___full-reconstructed___cosmics___90___X___X___X___X___X___X___X
# file_type detector and run_type protodune-sp and DUNE.campaign RITM1312299 and version v09_09_01 and data_tier full-reconstructed and data_stream cosmics and detector.hv_value 90  {'file_count': 312, 'total_file_size': 667426378433, 'total_event_count': 18468}
# new requestid TAG_mc___fardet-vd___RITM1331650___RITM1331650___v09_42_04_00___full-reconstructed___out1___X___X___X___X___X___X___X___X
# file_type mc and run_type fardet-vd and DUNE.requestid RITM1331650 and DUNE.campaign RITM1331650 and version v09_42_04_00 and data_tier full-reconstructed and data_stream out1  {'file_count': 103, 'total_file_size': 14820713784, 'total_event_count': 102010}
# new requestid TAG_detector___protodune-sp___X___RITM1312299___v09_09_01___full-reconstructed___cosmics___45___X___X___X___X___X___X___X
# file_type detector and run_type protodune-sp and DUNE.campaign RITM1312299 and version v09_09_01 and data_tier full-reconstructed and data_stream cosmics and detector.hv_value 45  {'file_count': 218, 'total_file_size': 475662415629, 'total_event_count': 13489}
# new requestid TAG_detector___protodune-sp___X___RITM1312299___v09_09_01___full-reconstructed___cosmics___135___X___X___X___X___X___X___X
# file_type detector and run_type protodune-sp and DUNE.campaign RITM1312299 and version v09_09_01 and data_tier full-reconstructed and data_stream cosmics and detector.hv_value 135  {'file_count': 984, 'total_file_size': 2185025590943, 'total_event_count': 65164}
# new requestid TAG_detector___protodune-sp___X___RITM1312299___v09_09_01___full-reconstructed___cosmics___160___X___X___X___X___X___X___X
# file_type detector and run_type protodune-sp and DUNE.campaign RITM1312299 and version v09_09_01 and data_tier full-reconstructed and data_stream cosmics and detector.hv_value 160  {'file_count': 386, 'total_file_size': 837326119800, 'total_event_count': 27902}
# new requestid TAG_detector___protodune-sp___X___RITM1312299___v09_30_00___reco-recalibrated___cosmics___120___X___X___X___X___X___X___X
# file_type detector and run_type protodune-sp and DUNE.campaign RITM1312299 and version v09_30_00 and data_tier reco-recalibrated and data_stream cosmics and detector.hv_value 120  {'file_count': 807, 'total_file_size': 1865624376643, 'total_event_count': 64584}
# new requestid TAG_detector___protodune-sp___X___RITM1312299___v09_09_01___full-reconstructed___cosmics___130___X___X___X___X___X___X___X
# file_type detector and run_type protodune-sp and DUNE.campaign RITM1312299 and version v09_09_01 and data_tier full-reconstructed and data_stream cosmics and detector.hv_value 130  {'file_count': 675, 'total_file_size': 1554924650276, 'total_event_count': 46778}
# new requestid TAG_detector___protodune-sp___X___RITM1312299___v09_30_00___reco-recalibrated___cosmics___0___X___X___X___X___X___X___X
# file_type detector and run_type protodune-sp and DUNE.campaign RITM1312299 and version v09_30_00 and data_tier reco-recalibrated and data_stream cosmics and detector.hv_value 0  {'file_count': 30, 'total_file_size': 73584314715, 'total_event_count': 21499}
# new requestid TAG_detector___protodune-sp___X___RITM1312299___v09_30_00___reco-recalibrated___cosmics___135___X___X___X___X___X___X___X
# file_type detector and run_type protodune-sp and DUNE.campaign RITM1312299 and version v09_30_00 and data_tier reco-recalibrated and data_stream cosmics and detector.hv_value 135  {'file_count': 424, 'total_file_size': 1016170975953, 'total_event_count': 28046}
# new requestid TAG_detector___protodune-sp___X___RITM1312299___v09_30_00___reco-recalibrated___cosmics___45___X___X___X___X___X___X___X
# file_type detector and run_type protodune-sp and DUNE.campaign RITM1312299 and version v09_30_00 and data_tier reco-recalibrated and data_stream cosmics and detector.hv_value 45  {'file_count': 152, 'total_file_size': 354572171076, 'total_event_count': 9388}
# new requestid TAG_detector___protodune-sp___X___RITM1312299___v09_30_00___reco-recalibrated___cosmics___18___X___X___X___X___X___X___X
# file_type detector and run_type protodune-sp and DUNE.campaign RITM1312299 and version v09_30_00 and data_tier reco-recalibrated and data_stream cosmics and detector.hv_value 18  {'file_count': 171, 'total_file_size': 106777258323, 'total_event_count': 10431}
# new requestid TAG_detector___protodune-sp___X___RITM1312299___v09_30_00___reco-recalibrated___cosmics___90___X___X___X___X___X___X___X
# file_type detector and run_type protodune-sp and DUNE.campaign RITM1312299 and version v09_30_00 and data_tier reco-recalibrated and data_stream cosmics and detector.hv_value 90  {'file_count': 170, 'total_file_size': 369159926125, 'total_event_count': 9594}
# new requestid TAG_detector___vd-coldbox-top___X___VD_coldbox_TDE_2021___v09_44_00_02___full-reconstructed___test___X___X___X___X___X___X___X___X
# file_type detector and run_type vd-coldbox-top and DUNE.campaign VD_coldbox_TDE_2021 and version v09_44_00_02 and data_tier full-reconstructed and data_stream test  {'file_count': 842, 'total_file_size': 1187326326957, 'total_event_count': 92490}
# new requestid TAG_mc___physics___RITM1331140___RITM1331140___v09_44_00_02___full-reconstructed___out1___X___1.0___1.0___35ms___beam_cosmics___no___yes___1
# file_type mc and run_type physics and DUNE.requestid RITM1331140 and DUNE.campaign RITM1331140 and version v09_44_00_02 and data_tier full-reconstructed and data_stream out1 and beam.momentum 1.0 and DUNE_MC.beam_energy 1.0 and DUNE_MC.electron_lifetime 35ms and DUNE_MC.generators beam_cosmics and DUNE_MC.liquid_flow no and DUNE_MC.space_charge yes and DUNE_MC.with_cosmics 1  {'file_count': 363, 'total_file_size': 1278010516344, 'total_event_count': 3630}
# new requestid TAG_mc___physics___RITM1331140___RITM1331140___v09_44_00_02___full-reconstructed___out1___X___1.0___1.0___35ms___beam_cosmics___no___no___1
# file_type mc and run_type physics and DUNE.requestid RITM1331140 and DUNE.campaign RITM1331140 and version v09_44_00_02 and data_tier full-reconstructed and data_stream out1 and beam.momentum 1.0 and DUNE_MC.beam_energy 1.0 and DUNE_MC.electron_lifetime 35ms and DUNE_MC.generators beam_cosmics and DUNE_MC.liquid_flow no and DUNE_MC.space_charge no and DUNE_MC.with_cosmics 1  {'file_count': 363, 'total_file_size': 1272017589829, 'total_event_count': 3630}
# new requestid TAG_mc___protodune-sp___RITM1331140___RITM1331140___v09_44_00_02___reco-recalibrated___out1___X___1.0___1.0___35ms___beam_cosmics___no___yes___1
# file_type mc and run_type protodune-sp and DUNE.requestid RITM1331140 and DUNE.campaign RITM1331140 and version v09_44_00_02 and data_tier reco-recalibrated and data_stream out1 and beam.momentum 1.0 and DUNE_MC.beam_energy 1.0 and DUNE_MC.electron_lifetime 35ms and DUNE_MC.generators beam_cosmics and DUNE_MC.liquid_flow no and DUNE_MC.space_charge yes and DUNE_MC.with_cosmics 1  {'file_count': 2810, 'total_file_size': 9904183052394, 'total_event_count': 28100}
# new requestid TAG_mc___protodune-sp___RITM1331140___RITM1331140___v09_44_00_02___reco-recalibrated___out1___X___1.0___1.0___35ms___beam_cosmics___no___no___1
# file_type mc and run_type protodune-sp and DUNE.requestid RITM1331140 and DUNE.campaign RITM1331140 and version v09_44_00_02 and data_tier reco-recalibrated and data_stream out1 and beam.momentum 1.0 and DUNE_MC.beam_energy 1.0 and DUNE_MC.electron_lifetime 35ms and DUNE_MC.generators beam_cosmics and DUNE_MC.liquid_flow no and DUNE_MC.space_charge no and DUNE_MC.with_cosmics 1  {'file_count': 2785, 'total_file_size': 9773364735002, 'total_event_count': 27850}
# new requestid TAG_mc___fardet-sp___RITM1355274___RITM1355274___v09_46_00_00___full-reconstructed___out1___X___X___X___X___NNBarAtm_hA_BR___X___X___X
# file_type mc and run_type fardet-sp and DUNE.requestid RITM1355274 and DUNE.campaign RITM1355274 and version v09_46_00_00 and data_tier full-reconstructed and data_stream out1 and DUNE_MC.generators NNBarAtm_hA_BR  {'file_count': 19817, 'total_file_size': 28785469425084, 'total_event_count': 4954250}
# new requestid TAG_mc___fardet-sp___RITM1355274___MC_Winter2022___v09_47_00_01___full-reconstructed___out1___X___X___X___X___NNBarAtm_hA_LFG___X___X___X
# file_type mc and run_type fardet-sp and DUNE.requestid RITM1355274 and DUNE.campaign MC_Winter2022 and version v09_47_00_01 and data_tier full-reconstructed and data_stream out1 and DUNE_MC.generators NNBarAtm_hA_LFG  {'file_count': 9950, 'total_file_size': 11369854027646, 'total_event_count': 1990050}
# new requestid TAG_mc___fardet-sp___RITM1355274___MC_Winter2022___v09_47_00_01___full-reconstructed___out1___X___X___X___X___NNBarAtm_hA_ESF___X___X___X
# file_type mc and run_type fardet-sp and DUNE.requestid RITM1355274 and DUNE.campaign MC_Winter2022 and version v09_47_00_01 and data_tier full-reconstructed and data_stream out1 and DUNE_MC.generators NNBarAtm_hA_ESF  {'file_count': 9923, 'total_file_size': 11818290499835, 'total_event_count': 1984650}
# new requestid TAG_mc___fardet-sp___RITM1355274___MC_Winter2022___v09_47_00_01___full-reconstructed___out1___X___X___X___X___NNBarAtm_hN_BR___X___X___X
# file_type mc and run_type fardet-sp and DUNE.requestid RITM1355274 and DUNE.campaign MC_Winter2022 and version v09_47_00_01 and data_tier full-reconstructed and data_stream out1 and DUNE_MC.generators NNBarAtm_hN_BR  {'file_count': 8050, 'total_file_size': 9350452850348, 'total_event_count': 1610050}
# new requestid TAG_mc___fardet-sp___RITM1355274___MC_Winter2022___v09_47_00_01___full-reconstructed___out1___X___X___X___X___NNBarAtm_hN_LFG___X___X___X
# file_type mc and run_type fardet-sp and DUNE.requestid RITM1355274 and DUNE.campaign MC_Winter2022 and version v09_47_00_01 and data_tier full-reconstructed and data_stream out1 and DUNE_MC.generators NNBarAtm_hN_LFG  {'file_count': 9949, 'total_file_size': 11430443796410, 'total_event_count': 1989850}
# new requestid TAG_mc___fardet-sp___RITM1355274___MC_Winter2022___v09_47_00_01___full-reconstructed___out1___X___X___X___X___NNBarAtm_hN_ESF___X___X___X
# file_type mc and run_type fardet-sp and DUNE.requestid RITM1355274 and DUNE.campaign MC_Winter2022 and version v09_47_00_01 and data_tier full-reconstructed and data_stream out1 and DUNE_MC.generators NNBarAtm_hN_ESF  {'file_count': 9942, 'total_file_size': 12238263129071, 'total_event_count': 1988450}
# new requestid TAG_mc___fardet-sp___RITM1355274___MC_Winter2022___v09_47_00_01___full-reconstructed___out1___X___X___X___X___protondecay_hA_LocalFG___X___X___X
# file_type mc and run_type fardet-sp and DUNE.requestid RITM1355274 and DUNE.campaign MC_Winter2022 and version v09_47_00_01 and data_tier full-reconstructed and data_stream out1 and DUNE_MC.generators protondecay_hA_LocalFG  {'file_count': 250, 'total_file_size': 208547924911, 'total_event_count': 99610}
# new requestid TAG_mc___fardet-sp___RITM1355274___MC_Winter2022___v09_47_00_01___full-reconstructed___out1___X___X___X___X___protondecay_hA_BodekRitchie___X___X___X
# file_type mc and run_type fardet-sp and DUNE.requestid RITM1355274 and DUNE.campaign MC_Winter2022 and version v09_47_00_01 and data_tier full-reconstructed and data_stream out1 and DUNE_MC.generators protondecay_hA_BodekRitchie  {'file_count': 250, 'total_file_size': 209374627301, 'total_event_count': 100000}
# new requestid TAG_mc___fardet-sp___RITM1355274___MC_Winter2022___v09_47_00_01___full-reconstructed___out1___X___X___X___X___protondecay_hN_LocalFG___X___X___X
# file_type mc and run_type fardet-sp and DUNE.requestid RITM1355274 and DUNE.campaign MC_Winter2022 and version v09_47_00_01 and data_tier full-reconstructed and data_stream out1 and DUNE_MC.generators protondecay_hN_LocalFG  {'file_count': 250, 'total_file_size': 217690682160, 'total_event_count': 100000}
# new requestid TAG_mc___fardet-sp___RITM1355274___MC_Winter2022___v09_47_00_01___full-reconstructed___out1___X___X___X___X___protondecay_hN_BodekRitchie___X___X___X
# file_type mc and run_type fardet-sp and DUNE.requestid RITM1355274 and DUNE.campaign MC_Winter2022 and version v09_47_00_01 and data_tier full-reconstructed and data_stream out1 and DUNE_MC.generators protondecay_hN_BodekRitchie  {'file_count': 250, 'total_file_size': 217910480610, 'total_event_count': 100000}
# new requestid TAG_mc___fardet-sp___RITM1355274___MC_Winter2022___v09_47_00_01___full-reconstructed___out1___X___X___X___X___protondecay_hA_EffSF___X___X___X
# file_type mc and run_type fardet-sp and DUNE.requestid RITM1355274 and DUNE.campaign MC_Winter2022 and version v09_47_00_01 and data_tier full-reconstructed and data_stream out1 and DUNE_MC.generators protondecay_hA_EffSF  {'file_count': 250, 'total_file_size': 214268480764, 'total_event_count': 100000}
# new requestid TAG_mc___fardet-sp___RITM1355274___MC_Winter2022___v09_47_00_01___full-reconstructed___out1___X___X___X___X___protondecay_hN_EffSF___X___X___X
# file_type mc and run_type fardet-sp and DUNE.requestid RITM1355274 and DUNE.campaign MC_Winter2022 and version v09_47_00_01 and data_tier full-reconstructed and data_stream out1 and DUNE_MC.generators protondecay_hN_EffSF  {'file_count': 248, 'total_file_size': 224802912496, 'total_event_count': 99200}
# new requestid TAG_mc___fardet-sp___RITM1355274___MC_Winter2022___v09_47_00_01___full-reconstructed___out1___X___X___X___X___legacynnbar_hA_LocalFG___X___X___X
# file_type mc and run_type fardet-sp and DUNE.requestid RITM1355274 and DUNE.campaign MC_Winter2022 and version v09_47_00_01 and data_tier full-reconstructed and data_stream out1 and DUNE_MC.generators legacynnbar_hA_LocalFG  {'file_count': 250, 'total_file_size': 671532768653, 'total_event_count': 100000}
# new requestid TAG_mc___fardet-sp___RITM1355274___MC_Winter2022___v09_47_00_01___full-reconstructed___out1___X___X___X___X___legacynnbar_hA_EffSF___X___X___X
# file_type mc and run_type fardet-sp and DUNE.requestid RITM1355274 and DUNE.campaign MC_Winter2022 and version v09_47_00_01 and data_tier full-reconstructed and data_stream out1 and DUNE_MC.generators legacynnbar_hA_EffSF  {'file_count': 246, 'total_file_size': 705908706425, 'total_event_count': 98400}
# new requestid TAG_mc___fardet-sp___RITM1355274___MC_Winter2022___v09_47_00_01___full-reconstructed___out1___X___X___X___X___legacynnbar_hN_BodekRitchie___X___X___X
# file_type mc and run_type fardet-sp and DUNE.requestid RITM1355274 and DUNE.campaign MC_Winter2022 and version v09_47_00_01 and data_tier full-reconstructed and data_stream out1 and DUNE_MC.generators legacynnbar_hN_BodekRitchie  {'file_count': 250, 'total_file_size': 712884115752, 'total_event_count': 100000}
# new requestid TAG_mc___fardet-sp___RITM1355274___MC_Winter2022___v09_47_00_01___full-reconstructed___out1___X___X___X___X___legacynnbar_hN_LocalFG___X___X___X
# file_type mc and run_type fardet-sp and DUNE.requestid RITM1355274 and DUNE.campaign MC_Winter2022 and version v09_47_00_01 and data_tier full-reconstructed and data_stream out1 and DUNE_MC.generators legacynnbar_hN_LocalFG  {'file_count': 249, 'total_file_size': 703646076491, 'total_event_count': 99600}
# new requestid TAG_mc___fardet-sp___RITM1355274___MC_Winter2022___v09_47_00_01___full-reconstructed___out1___X___X___X___X___legacynnbar_hN_EffSF___X___X___X
# file_type mc and run_type fardet-sp and DUNE.requestid RITM1355274 and DUNE.campaign MC_Winter2022 and version v09_47_00_01 and data_tier full-reconstructed and data_stream out1 and DUNE_MC.generators legacynnbar_hN_EffSF  {'file_count': 249, 'total_file_size': 807355785266, 'total_event_count': 99600}
# new requestid TAG_mc___fardet-sp___RITM1355274___MC_Winter2022___v09_47_00_01___full-reconstructed___out1___X___X___X___X___legacynnbar_hA_BodekRitchie___X___X___X
# file_type mc and run_type fardet-sp and DUNE.requestid RITM1355274 and DUNE.campaign MC_Winter2022 and version v09_47_00_01 and data_tier full-reconstructed and data_stream out1 and DUNE_MC.generators legacynnbar_hA_BodekRitchie  {'file_count': 250, 'total_file_size': 676551452586, 'total_event_count': 100000}
# new requestid TAG_mc___fardet-hd___RITM1355274___MC_Winter2022___v09_47_00_01___full-reconstructed___out1___X___X___X___X___scalar_Ar_m05_b10_G19_00a_20220302T020738___X___X___X
# file_type mc and run_type fardet-hd and DUNE.requestid RITM1355274 and DUNE.campaign MC_Winter2022 and version v09_47_00_01 and data_tier full-reconstructed and data_stream out1 and DUNE_MC.generators scalar_Ar_m05_b10_G19_00a_20220302T020738  {'file_count': 765, 'total_file_size': 1070460090376, 'total_event_count': 95625}
# new requestid TAG_mc___fardet-hd___RITM1355274___MC_Winter2022___v09_47_00_01___full-reconstructed___out1___X___X___X___X___scalar_Ar_m05_b10_G19_00b_20220302T021005___X___X___X
# file_type mc and run_type fardet-hd and DUNE.requestid RITM1355274 and DUNE.campaign MC_Winter2022 and version v09_47_00_01 and data_tier full-reconstructed and data_stream out1 and DUNE_MC.generators scalar_Ar_m05_b10_G19_00b_20220302T021005  {'file_count': 496, 'total_file_size': 1136334582283, 'total_event_count': 99200}
# new requestid TAG_mc___fardet-hd___RITM1355274___MC_Winter2022___v09_47_00_01___full-reconstructed___out1___X___X___X___X___scalar_Ar_m05_b10_G19_01b_20220302T042524___X___X___X
# file_type mc and run_type fardet-hd and DUNE.requestid RITM1355274 and DUNE.campaign MC_Winter2022 and version v09_47_00_01 and data_tier full-reconstructed and data_stream out1 and DUNE_MC.generators scalar_Ar_m05_b10_G19_01b_20220302T042524  {'file_count': 498, 'total_file_size': 1135697601278, 'total_event_count': 99600}
# new requestid TAG_mc___fardet-hd___RITM1355274___MC_Winter2022___v09_47_00_01___full-reconstructed___out1___X___X___X___X___scalar_Ar_m05_b10_G19_02a_20220302T042720___X___X___X
# file_type mc and run_type fardet-hd and DUNE.requestid RITM1355274 and DUNE.campaign MC_Winter2022 and version v09_47_00_01 and data_tier full-reconstructed and data_stream out1 and DUNE_MC.generators scalar_Ar_m05_b10_G19_02a_20220302T042720  {'file_count': 498, 'total_file_size': 1138739370832, 'total_event_count': 99600}
# new requestid TAG_mc___fardet-hd___RITM1355274___MC_Winter2022___v09_47_00_01___full-reconstructed___out1___X___X___X___X___scalar_Ar_m05_b10_G19_01a_20220302T042251___X___X___X
# file_type mc and run_type fardet-hd and DUNE.requestid RITM1355274 and DUNE.campaign MC_Winter2022 and version v09_47_00_01 and data_tier full-reconstructed and data_stream out1 and DUNE_MC.generators scalar_Ar_m05_b10_G19_01a_20220302T042251  {'file_count': 496, 'total_file_size': 1112091922290, 'total_event_count': 99200}
# new requestid TAG_mc___fardet-hd___RITM1355274___MC_Winter2022___v09_47_00_01___full-reconstructed___out1___X___X___X___X___scalar_Ar_m05_b1p1_G19_00a_20220302T023343___X___X___X
# file_type mc and run_type fardet-hd and DUNE.requestid RITM1355274 and DUNE.campaign MC_Winter2022 and version v09_47_00_01 and data_tier full-reconstructed and data_stream out1 and DUNE_MC.generators scalar_Ar_m05_b1p1_G19_00a_20220302T023343  {'file_count': 500, 'total_file_size': 53653466129, 'total_event_count': 100000}
# new requestid TAG_mc___fardet-hd___RITM1355274___MC_Winter2022___v09_47_00_01___full-reconstructed___out1___X___X___X___X___scalar_Ar_m05_b1p1_G19_01a_20220302T043327___X___X___X
# file_type mc and run_type fardet-hd and DUNE.requestid RITM1355274 and DUNE.campaign MC_Winter2022 and version v09_47_00_01 and data_tier full-reconstructed and data_stream out1 and DUNE_MC.generators scalar_Ar_m05_b1p1_G19_01a_20220302T043327  {'file_count': 500, 'total_file_size': 51453367021, 'total_event_count': 100000}
# new requestid TAG_mc___fardet-hd___RITM1355274___MC_Winter2022___v09_47_00_01___full-reconstructed___out1___X___X___X___X___scalar_Ar_m05_b1p1_G19_02a_20220302T043706___X___X___X
# file_type mc and run_type fardet-hd and DUNE.requestid RITM1355274 and DUNE.campaign MC_Winter2022 and version v09_47_00_01 and data_tier full-reconstructed and data_stream out1 and DUNE_MC.generators scalar_Ar_m05_b1p1_G19_02a_20220302T043706  {'file_count': 499, 'total_file_size': 61010819831, 'total_event_count': 99800}
# new requestid TAG_mc___fardet-hd___RITM1355274___MC_Winter2022___v09_47_00_01___full-reconstructed___out1___X___X___X___X___scalar_Ar_m05_b1p1_G19_01b_20220302T043529___X___X___X
# file_type mc and run_type fardet-hd and DUNE.requestid RITM1355274 and DUNE.campaign MC_Winter2022 and version v09_47_00_01 and data_tier full-reconstructed and data_stream out1 and DUNE_MC.generators scalar_Ar_m05_b1p1_G19_01b_20220302T043529  {'file_count': 500, 'total_file_size': 51367477081, 'total_event_count': 100000}
# new requestid TAG_mc___fardet-hd___RITM1355274___MC_Winter2022___v09_47_00_01___full-reconstructed___out1___X___X___X___X___scalar_Ar_m05_b1p1_G19_02b_20220302T043920___X___X___X
# file_type mc and run_type fardet-hd and DUNE.requestid RITM1355274 and DUNE.campaign MC_Winter2022 and version v09_47_00_01 and data_tier full-reconstructed and data_stream out1 and DUNE_MC.generators scalar_Ar_m05_b1p1_G19_02b_20220302T043920  {'file_count': 500, 'total_file_size': 95856644500, 'total_event_count': 100000}
# new requestid TAG_mc___fardet-hd___RITM1355274___MC_Winter2022___v09_47_00_01___full-reconstructed___out1___X___X___X___X___scalar_Ar_m05_b1p5_G19_00a_20220302T025602___X___X___X
# file_type mc and run_type fardet-hd and DUNE.requestid RITM1355274 and DUNE.campaign MC_Winter2022 and version v09_47_00_01 and data_tier full-reconstructed and data_stream out1 and DUNE_MC.generators scalar_Ar_m05_b1p5_G19_00a_20220302T025602  {'file_count': 500, 'total_file_size': 174924620335, 'total_event_count': 100000}
# new requestid TAG_mc___fardet-hd___RITM1355274___MC_Winter2022___v09_47_00_01___full-reconstructed___out1___X___X___X___X___scalar_Ar_m05_b1p5_G19_00b_20220302T025804___X___X___X
# file_type mc and run_type fardet-hd and DUNE.requestid RITM1355274 and DUNE.campaign MC_Winter2022 and version v09_47_00_01 and data_tier full-reconstructed and data_stream out1 and DUNE_MC.generators scalar_Ar_m05_b1p5_G19_00b_20220302T025804  {'file_count': 497, 'total_file_size': 182493275577, 'total_event_count': 99400}
# new requestid TAG_mc___fardet-hd___RITM1355274___MC_Winter2022___v09_47_00_01___full-reconstructed___out1___X___X___X___X___scalar_Ar_m05_b1p1_G19_00b_20220302T023549___X___X___X
# file_type mc and run_type fardet-hd and DUNE.requestid RITM1355274 and DUNE.campaign MC_Winter2022 and version v09_47_00_01 and data_tier full-reconstructed and data_stream out1 and DUNE_MC.generators scalar_Ar_m05_b1p1_G19_00b_20220302T023549  {'file_count': 500, 'total_file_size': 54001902616, 'total_event_count': 100000}
# new requestid TAG_mc___fardet-hd___RITM1355274___MC_Winter2022___v09_47_00_01___full-reconstructed___out1___X___X___X___X___scalar_Ar_m05_b1p5_G19_01b_20220302T044509___X___X___X
# file_type mc and run_type fardet-hd and DUNE.requestid RITM1355274 and DUNE.campaign MC_Winter2022 and version v09_47_00_01 and data_tier full-reconstructed and data_stream out1 and DUNE_MC.generators scalar_Ar_m05_b1p5_G19_01b_20220302T044509  {'file_count': 499, 'total_file_size': 182209849785, 'total_event_count': 99800}
# new requestid TAG_mc___fardet-hd___RITM1355274___MC_Winter2022___v09_47_00_01___full-reconstructed___out1___X___X___X___X___scalar_Ar_m05_b1p5_G19_02a_20220302T044652___X___X___X
# file_type mc and run_type fardet-hd and DUNE.requestid RITM1355274 and DUNE.campaign MC_Winter2022 and version v09_47_00_01 and data_tier full-reconstructed and data_stream out1 and DUNE_MC.generators scalar_Ar_m05_b1p5_G19_02a_20220302T044652  {'file_count': 498, 'total_file_size': 185308799980, 'total_event_count': 99600}
# new requestid TAG_mc___fardet-hd___RITM1355274___MC_Winter2022___v09_47_00_01___full-reconstructed___out1___X___X___X___X___scalar_Ar_m05_b1p5_G19_01a_20220302T044304___X___X___X
# file_type mc and run_type fardet-hd and DUNE.requestid RITM1355274 and DUNE.campaign MC_Winter2022 and version v09_47_00_01 and data_tier full-reconstructed and data_stream out1 and DUNE_MC.generators scalar_Ar_m05_b1p5_G19_01a_20220302T044304  {'file_count': 499, 'total_file_size': 174406892237, 'total_event_count': 99800}
# new requestid TAG_mc___fardet-hd___RITM1355274___MC_Winter2022___v09_47_00_01___full-reconstructed___out1___X___X___X___X___scalar_Ar_m05_b1p5_G19_02b_20220302T044904___X___X___X
# file_type mc and run_type fardet-hd and DUNE.requestid RITM1355274 and DUNE.campaign MC_Winter2022 and version v09_47_00_01 and data_tier full-reconstructed and data_stream out1 and DUNE_MC.generators scalar_Ar_m05_b1p5_G19_02b_20220302T044904  {'file_count': 498, 'total_file_size': 217865976257, 'total_event_count': 99600}
# new requestid TAG_mc___fardet-hd___RITM1355274___MC_Winter2022___v09_47_00_01___full-reconstructed___out1___X___X___X___X___scalar_Ar_m10_b1p1_G19_00a_20220302T023726___X___X___X
# file_type mc and run_type fardet-hd and DUNE.requestid RITM1355274 and DUNE.campaign MC_Winter2022 and version v09_47_00_01 and data_tier full-reconstructed and data_stream out1 and DUNE_MC.generators scalar_Ar_m10_b1p1_G19_00a_20220302T023726  {'file_count': 500, 'total_file_size': 55843937707, 'total_event_count': 100000}
# new requestid TAG_mc___fardet-hd___RITM1355274___MC_Winter2022___v09_47_00_01___full-reconstructed___out1___X___X___X___X___scalar_Ar_m10_b1p1_G19_00b_20220302T023927___X___X___X
# file_type mc and run_type fardet-hd and DUNE.requestid RITM1355274 and DUNE.campaign MC_Winter2022 and version v09_47_00_01 and data_tier full-reconstructed and data_stream out1 and DUNE_MC.generators scalar_Ar_m10_b1p1_G19_00b_20220302T023927  {'file_count': 500, 'total_file_size': 55676675923, 'total_event_count': 100000}
# new requestid TAG_mc___fardet-hd___RITM1355274___MC_Winter2022___v09_47_00_01___full-reconstructed___out1___X___X___X___X___scalar_Ar_m10_b1p1_G19_01a_20220302T024102___X___X___X
# file_type mc and run_type fardet-hd and DUNE.requestid RITM1355274 and DUNE.campaign MC_Winter2022 and version v09_47_00_01 and data_tier full-reconstructed and data_stream out1 and DUNE_MC.generators scalar_Ar_m10_b1p1_G19_01a_20220302T024102  {'file_count': 500, 'total_file_size': 53532895723, 'total_event_count': 100000}
# new requestid TAG_mc___fardet-hd___RITM1355274___MC_Winter2022___v09_47_00_01___full-reconstructed___out1___X___X___X___X___scalar_Ar_m10_b1p1_G19_01b_20220302T024302___X___X___X
# file_type mc and run_type fardet-hd and DUNE.requestid RITM1355274 and DUNE.campaign MC_Winter2022 and version v09_47_00_01 and data_tier full-reconstructed and data_stream out1 and DUNE_MC.generators scalar_Ar_m10_b1p1_G19_01b_20220302T024302  {'file_count': 500, 'total_file_size': 52959338981, 'total_event_count': 100000}
# new requestid TAG_mc___fardet-hd___RITM1355274___MC_Winter2022___v09_47_00_01___full-reconstructed___out1___X___X___X___X___scalar_Ar_m10_b1p1_G19_02b_20220302T024659___X___X___X
# file_type mc and run_type fardet-hd and DUNE.requestid RITM1355274 and DUNE.campaign MC_Winter2022 and version v09_47_00_01 and data_tier full-reconstructed and data_stream out1 and DUNE_MC.generators scalar_Ar_m10_b1p1_G19_02b_20220302T024659  {'file_count': 500, 'total_file_size': 98757908359, 'total_event_count': 100000}
# new requestid TAG_mc___fardet-hd___RITM1355274___MC_Winter2022___v09_47_00_01___full-reconstructed___out1___X___X___X___X___scalar_Ar_m10_b10_G19_00b_20220302T021422___X___X___X
# file_type mc and run_type fardet-hd and DUNE.requestid RITM1355274 and DUNE.campaign MC_Winter2022 and version v09_47_00_01 and data_tier full-reconstructed and data_stream out1 and DUNE_MC.generators scalar_Ar_m10_b10_G19_00b_20220302T021422  {'file_count': 494, 'total_file_size': 1265454895244, 'total_event_count': 98800}
# new requestid TAG_mc___fardet-hd___RITM1355274___MC_Winter2022___v09_47_00_01___full-reconstructed___out1___X___X___X___X___scalar_Ar_m10_b1p1_G19_02a_20220302T024441___X___X___X
# file_type mc and run_type fardet-hd and DUNE.requestid RITM1355274 and DUNE.campaign MC_Winter2022 and version v09_47_00_01 and data_tier full-reconstructed and data_stream out1 and DUNE_MC.generators scalar_Ar_m10_b1p1_G19_02a_20220302T024441  {'file_count': 500, 'total_file_size': 63786021924, 'total_event_count': 100000}
# new requestid TAG_mc___fardet-hd___RITM1355274___MC_Winter2022___v09_47_00_01___full-reconstructed___out1___X___X___X___X___scalar_Ar_m10_b1p5_G19_00b_20220302T030149___X___X___X
# file_type mc and run_type fardet-hd and DUNE.requestid RITM1355274 and DUNE.campaign MC_Winter2022 and version v09_47_00_01 and data_tier full-reconstructed and data_stream out1 and DUNE_MC.generators scalar_Ar_m10_b1p5_G19_00b_20220302T030149  {'file_count': 499, 'total_file_size': 194467913959, 'total_event_count': 99800}
# new requestid TAG_mc___fardet-hd___RITM1355274___MC_Winter2022___v09_47_00_01___full-reconstructed___out1___X___X___X___X___scalar_Ar_m10_b1p5_G19_00a_20220302T025944___X___X___X
# file_type mc and run_type fardet-hd and DUNE.requestid RITM1355274 and DUNE.campaign MC_Winter2022 and version v09_47_00_01 and data_tier full-reconstructed and data_stream out1 and DUNE_MC.generators scalar_Ar_m10_b1p5_G19_00a_20220302T025944  {'file_count': 500, 'total_file_size': 186604717967, 'total_event_count': 100000}
# new requestid TAG_mc___fardet-hd___RITM1355274___MC_Winter2022___v09_47_00_01___full-reconstructed___out1___X___X___X___X___scalar_Ar_m10_b1p5_G19_01b_20220302T030533___X___X___X
# file_type mc and run_type fardet-hd and DUNE.requestid RITM1355274 and DUNE.campaign MC_Winter2022 and version v09_47_00_01 and data_tier full-reconstructed and data_stream out1 and DUNE_MC.generators scalar_Ar_m10_b1p5_G19_01b_20220302T030533  {'file_count': 500, 'total_file_size': 194137444105, 'total_event_count': 100000}
# new requestid TAG_mc___fardet-hd___RITM1355274___MC_Winter2022___v09_47_00_01___full-reconstructed___out1___X___X___X___X___scalar_Ar_m10_b1p5_G19_01a_20220302T030329___X___X___X
# file_type mc and run_type fardet-hd and DUNE.requestid RITM1355274 and DUNE.campaign MC_Winter2022 and version v09_47_00_01 and data_tier full-reconstructed and data_stream out1 and DUNE_MC.generators scalar_Ar_m10_b1p5_G19_01a_20220302T030329  {'file_count': 499, 'total_file_size': 185213644758, 'total_event_count': 99800}
# new requestid TAG_mc___fardet-hd___RITM1355274___MC_Winter2022___v09_47_00_01___full-reconstructed___out1___X___X___X___X___scalar_Ar_m10_b1p5_G19_02b_20220302T030920___X___X___X
# file_type mc and run_type fardet-hd and DUNE.requestid RITM1355274 and DUNE.campaign MC_Winter2022 and version v09_47_00_01 and data_tier full-reconstructed and data_stream out1 and DUNE_MC.generators scalar_Ar_m10_b1p5_G19_02b_20220302T030920  {'file_count': 499, 'total_file_size': 230389232546, 'total_event_count': 99800}
# new requestid TAG_mc___fardet-hd___RITM1355274___MC_Winter2022___v09_47_00_01___full-reconstructed___out1___X___X___X___X___scalar_Ar_m10_b10_G19_01a_20220302T021614___X___X___X
# file_type mc and run_type fardet-hd and DUNE.requestid RITM1355274 and DUNE.campaign MC_Winter2022 and version v09_47_00_01 and data_tier full-reconstructed and data_stream out1 and DUNE_MC.generators scalar_Ar_m10_b10_G19_01a_20220302T021614  {'file_count': 496, 'total_file_size': 1245774639541, 'total_event_count': 99200}
# new requestid TAG_mc___fardet-hd___RITM1355274___MC_Winter2022___v09_47_00_01___full-reconstructed___out1___X___X___X___X___scalar_Ar_m10_b10_G19_02b_20220302T022300___X___X___X
# file_type mc and run_type fardet-hd and DUNE.requestid RITM1355274 and DUNE.campaign MC_Winter2022 and version v09_47_00_01 and data_tier full-reconstructed and data_stream out1 and DUNE_MC.generators scalar_Ar_m10_b10_G19_02b_20220302T022300  {'file_count': 493, 'total_file_size': 1316709686106, 'total_event_count': 98600}
# new requestid TAG_mc___fardet-hd___RITM1355274___MC_Winter2022___v09_47_00_01___full-reconstructed___out1___X___X___X___X___scalar_Ar_m10_b10_G19_00a_20220302T021159___X___X___X
# file_type mc and run_type fardet-hd and DUNE.requestid RITM1355274 and DUNE.campaign MC_Winter2022 and version v09_47_00_01 and data_tier full-reconstructed and data_stream out1 and DUNE_MC.generators scalar_Ar_m10_b10_G19_00a_20220302T021159  {'file_count': 493, 'total_file_size': 1235551261242, 'total_event_count': 98600}
# new requestid TAG_mc___fardet-hd___RITM1355274___MC_Winter2022___v09_47_00_01___full-reconstructed___out1___X___X___X___X___scalar_Ar_m05_b10_G19_02b_20220302T042950___X___X___X
# file_type mc and run_type fardet-hd and DUNE.requestid RITM1355274 and DUNE.campaign MC_Winter2022 and version v09_47_00_01 and data_tier full-reconstructed and data_stream out1 and DUNE_MC.generators scalar_Ar_m05_b10_G19_02b_20220302T042950  {'file_count': 497, 'total_file_size': 1196966966198, 'total_event_count': 99400}
# new requestid TAG_mc___fardet-hd___RITM1355274___MC_Winter2022___v09_47_00_01___full-reconstructed___out1___X___X___X___X___scalar_Ar_m10_b10_G19_02a_20220302T022032___X___X___X
# file_type mc and run_type fardet-hd and DUNE.requestid RITM1355274 and DUNE.campaign MC_Winter2022 and version v09_47_00_01 and data_tier full-reconstructed and data_stream out1 and DUNE_MC.generators scalar_Ar_m10_b10_G19_02a_20220302T022032  {'file_count': 492, 'total_file_size': 1251826389254, 'total_event_count': 98400}
# new requestid TAG_mc___fardet-hd___RITM1355274___MC_Winter2022___v09_47_00_01___full-reconstructed___out1___X___X___X___X___scalar_Ar_m20_b1p1_G19_00a_20220302T024835___X___X___X
# file_type mc and run_type fardet-hd and DUNE.requestid RITM1355274 and DUNE.campaign MC_Winter2022 and version v09_47_00_01 and data_tier full-reconstructed and data_stream out1 and DUNE_MC.generators scalar_Ar_m20_b1p1_G19_00a_20220302T024835  {'file_count': 500, 'total_file_size': 57038265741, 'total_event_count': 100000}
# new requestid TAG_mc___fardet-hd___RITM1355274___MC_Winter2022___v09_47_00_01___full-reconstructed___out1___X___X___X___X___scalar_Ar_m20_b1p1_G19_00b_20220302T025041___X___X___X
# file_type mc and run_type fardet-hd and DUNE.requestid RITM1355274 and DUNE.campaign MC_Winter2022 and version v09_47_00_01 and data_tier full-reconstructed and data_stream out1 and DUNE_MC.generators scalar_Ar_m20_b1p1_G19_00b_20220302T025041  {'file_count': 499, 'total_file_size': 56662989834, 'total_event_count': 99800}
# new requestid TAG_mc___fardet-hd___RITM1355274___MC_Winter2022___v09_47_00_01___full-reconstructed___out1___X___X___X___X___scalar_Ar_m20_b1p1_G19_01b_20220302T033215___X___X___X
# file_type mc and run_type fardet-hd and DUNE.requestid RITM1355274 and DUNE.campaign MC_Winter2022 and version v09_47_00_01 and data_tier full-reconstructed and data_stream out1 and DUNE_MC.generators scalar_Ar_m20_b1p1_G19_01b_20220302T033215  {'file_count': 500, 'total_file_size': 54017925232, 'total_event_count': 100000}
# new requestid TAG_mc___fardet-hd___RITM1355274___MC_Winter2022___v09_47_00_01___full-reconstructed___out1___X___X___X___X___scalar_Ar_m20_b1p1_G19_01a_20220302T033013___X___X___X
# file_type mc and run_type fardet-hd and DUNE.requestid RITM1355274 and DUNE.campaign MC_Winter2022 and version v09_47_00_01 and data_tier full-reconstructed and data_stream out1 and DUNE_MC.generators scalar_Ar_m20_b1p1_G19_01a_20220302T033013  {'file_count': 500, 'total_file_size': 54961808335, 'total_event_count': 100000}
# new requestid TAG_mc___fardet-hd___RITM1355274___MC_Winter2022___v09_47_00_01___full-reconstructed___out1___X___X___X___X___scalar_Ar_m20_b1p1_G19_02a_20220302T033354___X___X___X
# file_type mc and run_type fardet-hd and DUNE.requestid RITM1355274 and DUNE.campaign MC_Winter2022 and version v09_47_00_01 and data_tier full-reconstructed and data_stream out1 and DUNE_MC.generators scalar_Ar_m20_b1p1_G19_02a_20220302T033354  {'file_count': 500, 'total_file_size': 65052180479, 'total_event_count': 100000}
# new requestid TAG_mc___fardet-hd___RITM1355274___MC_Winter2022___v09_47_00_01___full-reconstructed___out1___X___X___X___X___scalar_Ar_m20_b1p1_G19_02b_20220302T033611___X___X___X
# file_type mc and run_type fardet-hd and DUNE.requestid RITM1355274 and DUNE.campaign MC_Winter2022 and version v09_47_00_01 and data_tier full-reconstructed and data_stream out1 and DUNE_MC.generators scalar_Ar_m20_b1p1_G19_02b_20220302T033611  {'file_count': 500, 'total_file_size': 99592929170, 'total_event_count': 100000}
# new requestid TAG_mc___fardet-hd___RITM1355274___MC_Winter2022___v09_47_00_01___full-reconstructed___out1___X___X___X___X___scalar_Ar_m20_b1p5_G19_00b_20220302T031300___X___X___X
# file_type mc and run_type fardet-hd and DUNE.requestid RITM1355274 and DUNE.campaign MC_Winter2022 and version v09_47_00_01 and data_tier full-reconstructed and data_stream out1 and DUNE_MC.generators scalar_Ar_m20_b1p5_G19_00b_20220302T031300  {'file_count': 500, 'total_file_size': 201040295837, 'total_event_count': 100000}
# new requestid TAG_mc___fardet-hd___RITM1355274___MC_Winter2022___v09_47_00_01___full-reconstructed___out1___X___X___X___X___scalar_Ar_m20_b1p5_G19_00a_20220302T031059___X___X___X
# file_type mc and run_type fardet-hd and DUNE.requestid RITM1355274 and DUNE.campaign MC_Winter2022 and version v09_47_00_01 and data_tier full-reconstructed and data_stream out1 and DUNE_MC.generators scalar_Ar_m20_b1p5_G19_00a_20220302T031059  {'file_count': 497, 'total_file_size': 191668702518, 'total_event_count': 99400}
# new requestid TAG_mc___fardet-hd___RITM1355274___MC_Winter2022___v09_47_00_01___full-reconstructed___out1___X___X___X___X___scalar_Ar_m20_b1p5_G19_01a_20220302T033959___X___X___X
# file_type mc and run_type fardet-hd and DUNE.requestid RITM1355274 and DUNE.campaign MC_Winter2022 and version v09_47_00_01 and data_tier full-reconstructed and data_stream out1 and DUNE_MC.generators scalar_Ar_m20_b1p5_G19_01a_20220302T033959  {'file_count': 496, 'total_file_size': 190011397618, 'total_event_count': 99200}
# new requestid TAG_mc___fardet-hd___RITM1355274___MC_Winter2022___v09_47_00_01___full-reconstructed___out1___X___X___X___X___scalar_Ar_m20_b1p5_G19_01b_20220302T034205___X___X___X
# file_type mc and run_type fardet-hd and DUNE.requestid RITM1355274 and DUNE.campaign MC_Winter2022 and version v09_47_00_01 and data_tier full-reconstructed and data_stream out1 and DUNE_MC.generators scalar_Ar_m20_b1p5_G19_01b_20220302T034205  {'file_count': 499, 'total_file_size': 199449643682, 'total_event_count': 99800}
# new requestid TAG_mc___fardet-hd___RITM1355274___MC_Winter2022___v09_47_00_01___full-reconstructed___out1___X___X___X___X___scalar_Ar_m20_b10_G19_01b_20220302T032150___X___X___X
# file_type mc and run_type fardet-hd and DUNE.requestid RITM1355274 and DUNE.campaign MC_Winter2022 and version v09_47_00_01 and data_tier full-reconstructed and data_stream out1 and DUNE_MC.generators scalar_Ar_m20_b10_G19_01b_20220302T032150  {'file_count': 497, 'total_file_size': 1345166738424, 'total_event_count': 99400}
# new requestid TAG_mc___fardet-hd___RITM1355274___MC_Winter2022___v09_47_00_01___full-reconstructed___out1___X___X___X___X___scalar_Ar_m20_b1p5_G19_02b_20220302T034601___X___X___X
# file_type mc and run_type fardet-hd and DUNE.requestid RITM1355274 and DUNE.campaign MC_Winter2022 and version v09_47_00_01 and data_tier full-reconstructed and data_stream out1 and DUNE_MC.generators scalar_Ar_m20_b1p5_G19_02b_20220302T034601  {'file_count': 498, 'total_file_size': 237822795222, 'total_event_count': 99600}
# new requestid TAG_mc___fardet-hd___RITM1355274___MC_Winter2022___v09_47_00_01___full-reconstructed___out1___X___X___X___X___scalar_Ar_m20_b1p5_G19_02a_20220302T034349___X___X___X
# file_type mc and run_type fardet-hd and DUNE.requestid RITM1355274 and DUNE.campaign MC_Winter2022 and version v09_47_00_01 and data_tier full-reconstructed and data_stream out1 and DUNE_MC.generators scalar_Ar_m20_b1p5_G19_02a_20220302T034349  {'file_count': 500, 'total_file_size': 204895525118, 'total_event_count': 100000}
# new requestid TAG_mc___fardet-hd___RITM1355274___MC_Winter2022___v09_47_00_01___full-reconstructed___out1___X___X___X___X___scalar_Ar_m10_b1p5_G19_02a_20220302T030713___X___X___X
# file_type mc and run_type fardet-hd and DUNE.requestid RITM1355274 and DUNE.campaign MC_Winter2022 and version v09_47_00_01 and data_tier full-reconstructed and data_stream out1 and DUNE_MC.generators scalar_Ar_m10_b1p5_G19_02a_20220302T030713  {'file_count': 499, 'total_file_size': 198693936534, 'total_event_count': 99800}
# new requestid TAG_mc___fardet-hd___RITM1355274___MC_Winter2022___v09_47_00_01___full-reconstructed___out1___X___X___X___X___scalar_Ar_m20_b10_G19_02a_20220302T032352___X___X___X
# file_type mc and run_type fardet-hd and DUNE.requestid RITM1355274 and DUNE.campaign MC_Winter2022 and version v09_47_00_01 and data_tier full-reconstructed and data_stream out1 and DUNE_MC.generators scalar_Ar_m20_b10_G19_02a_20220302T032352  {'file_count': 497, 'total_file_size': 1354178003922, 'total_event_count': 99400}
# new requestid TAG_mc___fardet-hd___RITM1355274___MC_Winter2022___v09_47_00_01___full-reconstructed___out1___X___X___X___X___scalar_Ar_m20_b10_G19_00a_20220302T022502___X___X___X
# file_type mc and run_type fardet-hd and DUNE.requestid RITM1355274 and DUNE.campaign MC_Winter2022 and version v09_47_00_01 and data_tier full-reconstructed and data_stream out1 and DUNE_MC.generators scalar_Ar_m20_b10_G19_00a_20220302T022502  {'file_count': 496, 'total_file_size': 1699480394008, 'total_event_count': 99200}
# new requestid TAG_mc___fardet-hd___RITM1355274___MC_Winter2022___v09_47_00_01___full-reconstructed___out1___X___X___X___X___scalar_Ar_m40_b1p1_G19_00a_20220302T025222___X___X___X
# file_type mc and run_type fardet-hd and DUNE.requestid RITM1355274 and DUNE.campaign MC_Winter2022 and version v09_47_00_01 and data_tier full-reconstructed and data_stream out1 and DUNE_MC.generators scalar_Ar_m40_b1p1_G19_00a_20220302T025222  {'file_count': 500, 'total_file_size': 57638810881, 'total_event_count': 100000}
# new requestid TAG_mc___fardet-hd___RITM1355274___MC_Winter2022___v09_47_00_01___full-reconstructed___out1___X___X___X___X___scalar_Ar_m40_b1p1_G19_01a_20220302T040124___X___X___X
# file_type mc and run_type fardet-hd and DUNE.requestid RITM1355274 and DUNE.campaign MC_Winter2022 and version v09_47_00_01 and data_tier full-reconstructed and data_stream out1 and DUNE_MC.generators scalar_Ar_m40_b1p1_G19_01a_20220302T040124  {'file_count': 500, 'total_file_size': 55372357819, 'total_event_count': 100000}
# new requestid TAG_mc___fardet-hd___RITM1355274___MC_Winter2022___v09_47_00_01___full-reconstructed___out1___X___X___X___X___scalar_Ar_m20_b10_G19_00b_20220302T022731___X___X___X
# file_type mc and run_type fardet-hd and DUNE.requestid RITM1355274 and DUNE.campaign MC_Winter2022 and version v09_47_00_01 and data_tier full-reconstructed and data_stream out1 and DUNE_MC.generators scalar_Ar_m20_b10_G19_00b_20220302T022731  {'file_count': 500, 'total_file_size': 1360966251002, 'total_event_count': 100000}
# new requestid TAG_mc___fardet-hd___RITM1355274___MC_Winter2022___v09_47_00_01___full-reconstructed___out1___X___X___X___X___scalar_Ar_m40_b1p1_G19_00b_20220302T025424___X___X___X
# file_type mc and run_type fardet-hd and DUNE.requestid RITM1355274 and DUNE.campaign MC_Winter2022 and version v09_47_00_01 and data_tier full-reconstructed and data_stream out1 and DUNE_MC.generators scalar_Ar_m40_b1p1_G19_00b_20220302T025424  {'file_count': 499, 'total_file_size': 56879807802, 'total_event_count': 99800}
# new requestid TAG_mc___fardet-hd___RITM1355274___MC_Winter2022___v09_47_00_01___full-reconstructed___out1___X___X___X___X___scalar_Ar_m40_b1p1_G19_01b_20220302T040328___X___X___X
# file_type mc and run_type fardet-hd and DUNE.requestid RITM1355274 and DUNE.campaign MC_Winter2022 and version v09_47_00_01 and data_tier full-reconstructed and data_stream out1 and DUNE_MC.generators scalar_Ar_m40_b1p1_G19_01b_20220302T040328  {'file_count': 500, 'total_file_size': 54564326294, 'total_event_count': 100000}
# new requestid TAG_mc___fardet-hd___RITM1355274___MC_Winter2022___v09_47_00_01___full-reconstructed___out1___X___X___X___X___scalar_Ar_m40_b1p1_G19_02a_20220302T040509___X___X___X
# file_type mc and run_type fardet-hd and DUNE.requestid RITM1355274 and DUNE.campaign MC_Winter2022 and version v09_47_00_01 and data_tier full-reconstructed and data_stream out1 and DUNE_MC.generators scalar_Ar_m40_b1p1_G19_02a_20220302T040509  {'file_count': 499, 'total_file_size': 66002292165, 'total_event_count': 99800}
# new requestid TAG_mc___fardet-hd___RITM1355274___MC_Winter2022___v09_47_00_01___full-reconstructed___out1___X___X___X___X___scalar_Ar_m20_b10_G19_02b_20220302T032623___X___X___X
# file_type mc and run_type fardet-hd and DUNE.requestid RITM1355274 and DUNE.campaign MC_Winter2022 and version v09_47_00_01 and data_tier full-reconstructed and data_stream out1 and DUNE_MC.generators scalar_Ar_m20_b10_G19_02b_20220302T032623  {'file_count': 496, 'total_file_size': 1414700078731, 'total_event_count': 99200}
# new requestid TAG_mc___fardet-hd___RITM1355274___MC_Winter2022___v09_47_00_01___full-reconstructed___out1___X___X___X___X___scalar_Ar_m40_b1p1_G19_02b_20220302T040828___X___X___X
# file_type mc and run_type fardet-hd and DUNE.requestid RITM1355274 and DUNE.campaign MC_Winter2022 and version v09_47_00_01 and data_tier full-reconstructed and data_stream out1 and DUNE_MC.generators scalar_Ar_m40_b1p1_G19_02b_20220302T040828  {'file_count': 499, 'total_file_size': 99809652470, 'total_event_count': 99800}
# new requestid TAG_mc___fardet-hd___RITM1355274___MC_Winter2022___v09_47_00_01___full-reconstructed___out1___X___X___X___X___scalar_Ar_m40_b10_G19_00b_20220302T023207___X___X___X
# file_type mc and run_type fardet-hd and DUNE.requestid RITM1355274 and DUNE.campaign MC_Winter2022 and version v09_47_00_01 and data_tier full-reconstructed and data_stream out1 and DUNE_MC.generators scalar_Ar_m40_b10_G19_00b_20220302T023207  {'file_count': 484, 'total_file_size': 1366175120583, 'total_event_count': 96800}
# new requestid TAG_mc___fardet-hd___RITM1355274___MC_Winter2022___v09_47_00_01___full-reconstructed___out1___X___X___X___X___scalar_Ar_m40_b1p5_G19_00b_20220302T031643___X___X___X
# file_type mc and run_type fardet-hd and DUNE.requestid RITM1355274 and DUNE.campaign MC_Winter2022 and version v09_47_00_01 and data_tier full-reconstructed and data_stream out1 and DUNE_MC.generators scalar_Ar_m40_b1p5_G19_00b_20220302T031643  {'file_count': 500, 'total_file_size': 204490060034, 'total_event_count': 100000}
# new requestid TAG_mc___fardet-hd___RITM1355274___MC_Winter2022___v09_47_00_01___full-reconstructed___out1___X___X___X___X___scalar_Ar_m40_b10_G19_00a_20220302T022930___X___X___X
# file_type mc and run_type fardet-hd and DUNE.requestid RITM1355274 and DUNE.campaign MC_Winter2022 and version v09_47_00_01 and data_tier full-reconstructed and data_stream out1 and DUNE_MC.generators scalar_Ar_m40_b10_G19_00a_20220302T022930  {'file_count': 498, 'total_file_size': 1377599920085, 'total_event_count': 99600}
# new requestid TAG_mc___fardet-hd___RITM1355274___MC_Winter2022___v09_47_00_01___full-reconstructed___out1___X___X___X___X___scalar_Ar_m40_b1p5_G19_00a_20220302T031439___X___X___X
# file_type mc and run_type fardet-hd and DUNE.requestid RITM1355274 and DUNE.campaign MC_Winter2022 and version v09_47_00_01 and data_tier full-reconstructed and data_stream out1 and DUNE_MC.generators scalar_Ar_m40_b1p5_G19_00a_20220302T031439  {'file_count': 500, 'total_file_size': 195050504883, 'total_event_count': 100000}
# new requestid TAG_mc___fardet-hd___RITM1355274___MC_Winter2022___v09_47_00_01___full-reconstructed___out1___X___X___X___X___scalar_Ar_m40_b10_G19_01a_20220302T035030___X___X___X
# file_type mc and run_type fardet-hd and DUNE.requestid RITM1355274 and DUNE.campaign MC_Winter2022 and version v09_47_00_01 and data_tier full-reconstructed and data_stream out1 and DUNE_MC.generators scalar_Ar_m40_b10_G19_01a_20220302T035030  {'file_count': 492, 'total_file_size': 1357947008498, 'total_event_count': 98400}
# new requestid TAG_mc___fardet-hd___RITM1355274___MC_Winter2022___v09_47_00_01___full-reconstructed___out1___X___X___X___X___scalar_Ar_m40_b1p5_G19_01b_20220302T041427___X___X___X
# file_type mc and run_type fardet-hd and DUNE.requestid RITM1355274 and DUNE.campaign MC_Winter2022 and version v09_47_00_01 and data_tier full-reconstructed and data_stream out1 and DUNE_MC.generators scalar_Ar_m40_b1p5_G19_01b_20220302T041427  {'file_count': 498, 'total_file_size': 202683427619, 'total_event_count': 99600}
# new requestid TAG_mc___fardet-hd___RITM1355274___MC_Winter2022___v09_47_00_01___full-reconstructed___out1___X___X___X___X___scalar_Ar_m40_b10_G19_01b_20220302T035301___X___X___X
# file_type mc and run_type fardet-hd and DUNE.requestid RITM1355274 and DUNE.campaign MC_Winter2022 and version v09_47_00_01 and data_tier full-reconstructed and data_stream out1 and DUNE_MC.generators scalar_Ar_m40_b10_G19_01b_20220302T035301  {'file_count': 484, 'total_file_size': 1360137495824, 'total_event_count': 96800}
# new requestid TAG_mc___fardet-hd___RITM1355274___MC_Winter2022___v09_47_00_01___full-reconstructed___out1___X___X___X___X___scalar_Ar_m40_b1p5_G19_01a_20220302T041220___X___X___X
# file_type mc and run_type fardet-hd and DUNE.requestid RITM1355274 and DUNE.campaign MC_Winter2022 and version v09_47_00_01 and data_tier full-reconstructed and data_stream out1 and DUNE_MC.generators scalar_Ar_m40_b1p5_G19_01a_20220302T041220  {'file_count': 499, 'total_file_size': 194475350848, 'total_event_count': 99800}
# new requestid TAG_mc___fardet-hd___RITM1355274___MC_Winter2022___v09_47_00_01___full-reconstructed___out1___X___X___X___X___scalar_Ar_m40_b1p5_G19_02a_20220302T041609___X___X___X
# file_type mc and run_type fardet-hd and DUNE.requestid RITM1355274 and DUNE.campaign MC_Winter2022 and version v09_47_00_01 and data_tier full-reconstructed and data_stream out1 and DUNE_MC.generators scalar_Ar_m40_b1p5_G19_02a_20220302T041609  {'file_count': 499, 'total_file_size': 208114709154, 'total_event_count': 99800}
# new requestid TAG_mc___fardet-hd___RITM1355274___MC_Winter2022___v09_47_00_01___full-reconstructed___out1___X___X___X___X___scalar_Ar_m40_b1p5_G19_02b_20220302T041820___X___X___X
# file_type mc and run_type fardet-hd and DUNE.requestid RITM1355274 and DUNE.campaign MC_Winter2022 and version v09_47_00_01 and data_tier full-reconstructed and data_stream out1 and DUNE_MC.generators scalar_Ar_m40_b1p5_G19_02b_20220302T041820  {'file_count': 500, 'total_file_size': 241974749793, 'total_event_count': 100000}
# new requestid TAG_mc___fardet-hd___RITM1355274___MC_Winter2022___v09_47_00_01___full-reconstructed___out1___X___X___X___X___scalar_Ar_m40_b10_G19_02a_20220302T035503___X___X___X
# file_type mc and run_type fardet-hd and DUNE.requestid RITM1355274 and DUNE.campaign MC_Winter2022 and version v09_47_00_01 and data_tier full-reconstructed and data_stream out1 and DUNE_MC.generators scalar_Ar_m40_b10_G19_02a_20220302T035503  {'file_count': 493, 'total_file_size': 1395980462729, 'total_event_count': 98600}
# new requestid TAG_mc___fardet-hd___RITM1355274___MC_Winter2022___v09_47_00_01___full-reconstructed___out1___X___X___X___X___scalar_Ar_m40_b10_G19_02b_20220302T035743___X___X___X
# file_type mc and run_type fardet-hd and DUNE.requestid RITM1355274 and DUNE.campaign MC_Winter2022 and version v09_47_00_01 and data_tier full-reconstructed and data_stream out1 and DUNE_MC.generators scalar_Ar_m40_b10_G19_02b_20220302T035743  {'file_count': 496, 'total_file_size': 1463575140583, 'total_event_count': 99200}
# new requestid TAG_detector___vd-coldbox-top___X___VD_coldbox_TDE_2021___v09_49_00d00___full-reconstructed___test___X___X___X___X___X___X___X___X
# file_type detector and run_type vd-coldbox-top and DUNE.campaign VD_coldbox_TDE_2021 and version v09_49_00d00 and data_tier full-reconstructed and data_stream test  {'file_count': 17921, 'total_file_size': 25259760056799, 'total_event_count': 1967719}
# new requestid TAG_detector___protodune-sp___X___RITM1382619___v09_09_01___full-reconstructed___cosmics___X___X___X___X___X___X___X___X
# file_type detector and run_type protodune-sp and DUNE.campaign RITM1382619 and version v09_09_01 and data_tier full-reconstructed and data_stream cosmics  {'file_count': 72580, 'total_file_size': 64866326286014, 'total_event_count': 2296178}
# new requestid TAG_detector___vd-coldbox-top___X___VD_coldbox_TDE_2021___v09_49_00d00___full-reconstructed___study___X___X___X___X___X___X___X___X
# file_type detector and run_type vd-coldbox-top and DUNE.campaign VD_coldbox_TDE_2021 and version v09_49_00d00 and data_tier full-reconstructed and data_stream study  {'file_count': 5460, 'total_file_size': 7212562676575, 'total_event_count': 598960}
# new requestid TAG_detector___dc4-vd-coldbox-bottom___X___dc4___raw___test___X___X___X___X___X___X___X___X
# file_type detector and run_type dc4-vd-coldbox-bottom and DUNE.campaign dc4 and data_tier raw and data_stream test  {'file_count': 49327, 'total_file_size': 211358810476112, 'total_event_count': 3056585}
# new requestid TAG_mc___physics___RITM1464893___FDHDSNProd1___v09_52_00d00___detector-simulated___out1___X___X___X___X___X___X___X___X
# file_type mc and run_type physics and DUNE.requestid RITM1464893 and DUNE.campaign FDHDSNProd1 and version v09_52_00d00 and data_tier detector-simulated and data_stream out1  {'file_count': 6400, 'total_file_size': 61485048255945, 'total_event_count': 1280000}
# new requestid TAG_mc___fardet-vd___RITM1457487___FDVDProd2___v09_53_00d02___pandora_info___out1___X___X___X___X___X___X___X___X

# %%
print ("processed", count, "records")
#print (descriplist)
fname = "requests.json"
if DEBUG: fname = "test.json"
f = open(fname,'w')
json.dump(descriplist,f,indent = 4)
f.close()

for x in descriplist:
    print (x, "\t events = ", descriplist[x]["total_event_count"], " \t size = ", descriplist[x]["total_file_size_GB"],"GB")

# %%
# for a in descriplist:
#     query =  "DUNE.requestid %s"%a
#     summary = samweb.listFilesSummary(query)
#     print (query, summary)
